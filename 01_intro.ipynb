# %%
# !git clone https://github.com/ItsMeAbby/DL-Workshop-1.git
# Out:
# Cloning into 'DL-Workshop-1'...
# remote: Enumerating objects: 374, done.
# remote: Counting objects: 100% (374/374), done.
# remote: Compressing objects: 100% (365/365), done.
# remote: Total 374 (delta 10), reused 373 (delta 9), pack-reused 0
# Receiving objects: 100% (374/374), 89.90 MiB | 28.71 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
cd /content/DL-Workshop-1
# Out:
# /content/DL-Workshop-1

# %% [markdown]
# # Your Deep Learning Journey

# %% [markdown]
# *Hello*, and thank you for letting us join you on your deep learning journey, however far along that you may be! In this session, we will tell you a little bit more about what to expect in these workshops, introduce the key concepts behind deep learning, and train our first models on different tasks. It doesn't matter if you don't come from a technical or a mathematical background (though it's okay if you do too!)

# %% [markdown]
# ## Deep Learning Is for Everyone

# %% [markdown]
# Deep learning is a computer technique to extract and transform data–-with use cases ranging from human speech recognition to animal imagery classification–-by using multiple layers of neural networks. Each of these layers takes its inputs from previous layers and progressively refines them. The layers are trained by algorithms that minimize their errors and improve their accuracy. In this way, the network learns to perform a specified task. We will discuss training algorithms in detail in the next section.

# %% [markdown]
# Deep learning has power, flexibility, and simplicity. That's why we believe it should be applied across many disciplines. These include the social and physical sciences, the arts, medicine, finance, scientific research, and many more. To give a personal example, despite having no background in medicine, Jeremy started Enlitic, a company that uses deep learning algorithms to diagnose illness and disease. Within months of starting the company, it was announced that its algorithm could identify malignant tumors [more accurately than radiologists](https://www.nytimes.com/2016/02/29/technology/the-promise-of-artificial-intelligence-unfolds-in-small-steps.html).
#
# Here's a list of some of the thousands of tasks in different areas at which deep learning, or methods heavily using deep learning, is now the best in the world:
#
# - Natural language processing (NLP):: Answering questions; speech recognition; summarizing documents; classifying documents; finding names, dates, etc. in documents; searching for articles mentioning a concept
# - Computer vision:: Satellite and drone imagery interpretation (e.g., for disaster resilience); face recognition; image captioning; reading traffic signs; locating pedestrians and vehicles in autonomous vehicles
# - Medicine:: Finding anomalies in radiology images, including CT, MRI, and X-ray images; counting features in pathology slides; measuring features in ultrasounds; diagnosing diabetic retinopathy
# - Biology:: Folding proteins; classifying proteins; many genomics tasks, such as tumor-normal sequencing and classifying clinically actionable genetic mutations; cell classification; analyzing protein/protein interactions
# - Image generation:: Colorizing images; increasing image resolution; removing noise from images; converting images to art in the style of famous artists
# - Recommendation systems:: Web search; product recommendations; home page layout
# - Playing games:: Chess, Go, most Atari video games, and many real-time strategy games
# - Robotics:: Handling objects that are challenging to locate (e.g., transparent, shiny, lacking texture) or hard to pick up
# - Other applications:: Financial and logistical forecasting, text to speech, and much more...

# %% [markdown]
# What is remarkable is that deep learning has such varied application yet nearly all of deep learning is based on a single type of model, the neural network.
#
# But neural networks are not in fact completely new. In order to have a wider perspective on the field, it is worth it to start with a bit of history.

# %% [markdown]
# ## How to Learn Deep Learning

# %% [markdown]
# In deep learning, it really helps if you have the motivation to fix your model to get it to do better. That's when you start learning the relevant theory. But you need to have the model in the first place. We teach almost everything through real examples. As we build out those examples, we go deeper and deeper, and we'll show you how to make your projects better and better. This means that you'll be gradually learning all the theoretical foundations you need, in context, in such a way that you'll see why it matters and how it works.
#
# So, here's our commitment to you. Throughout this session, we will follow these principles:
#
# - Teaching the *whole game*. We'll start by showing how to use a complete, working, very usable, state-of-the-art deep learning network to solve real-world problems, using simple, expressive tools. And then we'll gradually dig deeper and deeper into understanding how those tools are made, and how the tools that make those tools are made, and so on…
# - Always teaching through examples. We'll ensure that there is a context and a purpose that you can understand intuitively, rather than starting with algebraic symbol manipulation.
# - Simplifying as much as possible. We've spent years building tools and teaching methods that make previously complex topics very simple.
# - Removing barriers. Deep learning has, until now, been a very exclusive game. We're breaking it open, and ensuring that everyone can play.

# %% [markdown]
# The hardest part of deep learning is a little different: how do you know if you've got enough data, whether it is in the right format, if your model is training properly, and, if it's not, what you should do about it? That is why we believe in learning by doing. As with basic data science skills, with deep learning you only get better through practical experience. Trying to spend too much time on the theory can be counterproductive. The key is to just code and try to solve problems: the theory can come later, when you have context and motivation.
#
# There will be times when the journey will feel hard. Times where you feel stuck. Don't give up! Rewind through the notebook to find the last bit where you definitely weren't stuck, and then read slowly through from there to find the first thing that isn't clear. Then try some code experiments yourself, and Google around for more tutorials on whatever the issue you're stuck with is—often you'll find some different angle on the material might help it to click. Also, it's expected and normal to not understand everything (especially the code) on first reading. Trying to understand the material serially before proceeding can sometimes be hard. Sometimes things click into place after you get more context from parts down the road, from having a bigger picture. So if you do get stuck on a section, try moving on anyway and make a note to come back to it later.

# %% [markdown]
# What you will need to do to succeed however is to apply what you learn in this notebook to a personal project, and always persevere.

# %% [markdown]
# ### Your Projects and Your Mindset

# %% [markdown]
# Whether you're excited to identify if plants are diseased from pictures of their leaves, auto-generate knitting patterns, diagnose TB from X-rays, or determine when a raccoon is using your cat door, we will get you using deep learning on your own problems (via pre-trained models from others) as quickly as possible, and then will progressively drill into more details. You'll learn how to use deep learning to solve your own problems at state-of-the-art accuracy within the first 30 minutes of this session! (And feel free to skip straight there now if you're dying to get coding right away.) There is a pernicious myth out there that you need to have computing resources and datasets the size of those at Google to be able to do deep learning, but it's not true.
#
# So, what sorts of tasks make for good test cases? You could train your model to distinguish between Picasso and Monet paintings or to pick out pictures of your daughter instead of pictures of your son. It helps to focus on your hobbies and passions–-setting yourself four or five little projects rather than striving to solve a big, grand problem tends to work better when you're getting started. Since it is easy to get stuck, trying to be too ambitious too early can often backfire. Then, once you've got the basics mastered, aim to complete something you're really proud of!

# %% [markdown]
# Let's now focus on what you will learn, starting with the software.

# %% [markdown]
# ## The Software: PyTorch, fastai, and Jupyter

# %% [markdown]
# (And Why It Doesn't Matter)

# %% [markdown]
# We have found that PyTorch is the most flexible and expressive library for deep learning. It does not trade off speed for simplicity, but provides both.
#
# PyTorch works best as a low-level foundation library, providing the basic operations for higher-level functionality. The fastai library is the most popular library for adding this higher-level functionality on top of PyTorch. It's also particularly well suited to the purposes of this session, because it is unique in providing a deeply layered software architecture (there's even a [peer-reviewed academic paper](https://arxiv.org/abs/2002.04688) about this layered API). In this session, as we go deeper and deeper into the foundations of deep learning, we will also go deeper and deeper into the layers of fastai. This session covers version 2 of the fastai library, which is a from-scratch rewrite providing many unique features.

# %% [markdown]
# However, it doesn't really matter what software you learn, because it takes only a few days to learn to switch from one library to another. What really matters is learning the deep learning foundations and techniques properly. Our focus will be on using code that clearly expresses the concepts that you need to learn. Where we are teaching high-level concepts, we will use high-level fastai code. Where we are teaching low-level concepts, we will use low-level PyTorch, or even pure Python code.
#
# If it feels like new deep learning libraries are appearing at a rapid pace nowadays, then you need to be prepared for a much faster rate of change in the coming months and years. As more people enter the field, they will bring more skills and ideas, and try more things. You should assume that whatever specific libraries and software you learn today will be obsolete in a year or two. Just think about the number of changes in libraries and technology stacks that occur all the time in the world of web programming—a much more mature and slow-growing area than deep learning. We strongly believe that the focus in learning needs to be on understanding the underlying techniques and how to apply them in practice, and how to quickly build expertise in new tools and techniques as they are released.

# %% [markdown]
# Let's see it in practice and train our first model.

# %% [markdown]
# ## Your First Model

# %% [markdown]
# As we said before, we will teach you how to do things before we explain why they work. Following this top-down approach, we will begin by actually training an image classifier to recognize dogs and cats with almost 100% accuracy. To train this model and run our experiments, you will need to do some initial setup. Don't worry, it's not as hard as it looks.

# %% [markdown]
# >Do not skip the setup part even if it looks intimidating at first, especially if you have little or no experience using things like a terminal or the command line. Most of that is actually not necessary and you will find that the easiest servers can be set up with just your usual web browser. It is crucial that you run your own experiments in parallel with this notebook in order to learn.

# %% [markdown]
# ### Running Your First Notebook

# %% [markdown]
# You will be using this notebook to train a model that can recognize dog and cat photos. To do this, you'll be downloading a _dataset_ of dog and cat photos, and using that to _train a model_. A dataset is simply a bunch of data—it could be images, emails, financial indicators, sounds, or anything else. There are many datasets made freely available that are suitable for training models. Many of these datasets are created by academics to help advance research, many are made available for competitions (there are competitions where data scientists can compete to see who has the most accurate model!), and some are by-products of other processes (such as financial filings).

# %% [markdown]
# Click on the cell that begins with the line "# CLICK ME" to select it. The first character in that line indicates that what follows is a comment in Python, so it is ignored when executing the cell. The rest of the cell is, believe it or not, a complete system for creating and training a state-of-the-art model for recognizing cats versus dogs. So, let's train it now! To do so, just press Shift-Enter on your keyboard, or press the Play button on the toolbar. Then wait a few minutes while the following things happen:
#
# 1. A dataset called the [Oxford-IIIT Pet Dataset](http://www.robots.ox.ac.uk/~vgg/data/pets/) that contains 7,349 images of cats and dogs from 37 different breeds will be downloaded from the fast.ai datasets collection to the GPU server you are using, and will then be extracted.
# 2. A *pretrained model* that has already been trained on 1.3 million images, using a competition-winning model will be downloaded from the internet.
# 3. The pretrained model will be *fine-tuned* using the latest advances in transfer learning, to create a model that is specially customized for recognizing dogs and cats.
#
# The first two steps only need to be run once on your GPU server. If you run the cell again, it will use the dataset and model that have already been downloaded, rather than downloading them again. Let's take a look at the contents of the cell, and the results (<<first_training>>):

# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
from fastbook import *
# Out:
#      |████████████████████████████████| 720 kB 5.3 MB/s
#      |████████████████████████████████| 46 kB 3.9 MB/s
#      |████████████████████████████████| 189 kB 45.4 MB/s
#      |████████████████████████████████| 1.2 MB 35.2 MB/s
#      |████████████████████████████████| 56 kB 4.2 MB/s
#      |████████████████████████████████| 51 kB 299 kB/s
# Mounted at /content/gdrive

# %%
untar_data(URLs.PETS)/'images'
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='811712512' class='' max='811706944' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [811712512/811706944 00:09<00:00]
#     </div>
# Path('/root/.fastai/data/oxford-iiit-pet/images')

# %%
import os
os.makedirs('/content/images')
# !cp -avr /root/.fastai/data/oxford-iiit-pet/images /content/images
# Out:
# Streaming output truncated to the last 5000 lines.
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_81.jpg' -> '/content/images/images/keeshond_81.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_191.jpg' -> '/content/images/images/wheaten_terrier_191.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_142.jpg' -> '/content/images/images/beagle_142.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_87.jpg' -> '/content/images/images/pomeranian_87.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_180.jpg' -> '/content/images/images/Abyssinian_180.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_221.jpg' -> '/content/images/images/Bombay_221.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_105.jpg' -> '/content/images/images/basset_hound_105.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/great_pyrenees_200.jpg' -> '/content/images/images/great_pyrenees_200.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_48.jpg' -> '/content/images/images/american_pit_bull_terrier_48.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_108.jpg' -> '/content/images/images/Maine_Coon_108.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_108.jpg' -> '/content/images/images/samoyed_108.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_30.jpg' -> '/content/images/images/British_Shorthair_30.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_169.jpg' -> '/content/images/images/japanese_chin_169.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_169.jpg' -> '/content/images/images/British_Shorthair_169.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_75.jpg' -> '/content/images/images/basset_hound_75.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Ragdoll_83.jpg' -> '/content/images/images/Ragdoll_83.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_145.jpg' -> '/content/images/images/german_shorthaired_145.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/chihuahua_128.jpg' -> '/content/images/images/chihuahua_128.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_89.jpg' -> '/content/images/images/yorkshire_terrier_89.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_192.jpg' -> '/content/images/images/shiba_inu_192.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_20.jpg' -> '/content/images/images/english_cocker_spaniel_20.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_148.jpg' -> '/content/images/images/Maine_Coon_148.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/newfoundland_156.jpg' -> '/content/images/images/newfoundland_156.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_102.jpg' -> '/content/images/images/Maine_Coon_102.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_160.jpg' -> '/content/images/images/pug_160.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_setter_116.jpg' -> '/content/images/images/english_setter_116.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_119.jpg' -> '/content/images/images/havanese_119.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_73.jpg' -> '/content/images/images/Russian_Blue_73.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_197.jpg' -> '/content/images/images/Bengal_197.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_152.jpg' -> '/content/images/images/american_pit_bull_terrier_152.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_160.jpg' -> '/content/images/images/beagle_160.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_70.jpg' -> '/content/images/images/Bombay_70.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_115.jpg' -> '/content/images/images/Siamese_115.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_153.jpg' -> '/content/images/images/shiba_inu_153.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_126.jpg' -> '/content/images/images/saint_bernard_126.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_3.jpg' -> '/content/images/images/Abyssinian_3.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Persian_169.jpg' -> '/content/images/images/Persian_169.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_146.jpg' -> '/content/images/images/Bombay_146.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_155.jpg' -> '/content/images/images/beagle_155.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_63.jpg' -> '/content/images/images/german_shorthaired_63.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/chihuahua_78.jpg' -> '/content/images/images/chihuahua_78.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_54.jpg' -> '/content/images/images/american_bulldog_54.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_165.jpg' -> '/content/images/images/wheaten_terrier_165.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_61.jpg' -> '/content/images/images/Bombay_61.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_105.jpg' -> '/content/images/images/saint_bernard_105.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_150.jpg' -> '/content/images/images/yorkshire_terrier_150.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_183.jpg' -> '/content/images/images/saint_bernard_183.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_38.jpg' -> '/content/images/images/wheaten_terrier_38.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_82.jpg' -> '/content/images/images/staffordshire_bull_terrier_82.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_94.jpg' -> '/content/images/images/american_bulldog_94.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_124.jpg' -> '/content/images/images/keeshond_124.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_166.jpg' -> '/content/images/images/Abyssinian_166.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/leonberger_2.jpg' -> '/content/images/images/leonberger_2.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/newfoundland_19.jpg' -> '/content/images/images/newfoundland_19.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_87.jpg' -> '/content/images/images/wheaten_terrier_87.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_101.jpg' -> '/content/images/images/shiba_inu_101.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_178.jpg' -> '/content/images/images/pug_178.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_2.jpg' -> '/content/images/images/pug_2.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/chihuahua_187.jpg' -> '/content/images/images/chihuahua_187.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_setter_146.jpg' -> '/content/images/images/english_setter_146.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_100.jpg' -> '/content/images/images/saint_bernard_100.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_84.jpg' -> '/content/images/images/basset_hound_84.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_194.jpg' -> '/content/images/images/havanese_194.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_195.jpg' -> '/content/images/images/shiba_inu_195.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_178.jpg' -> '/content/images/images/miniature_pinscher_178.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_103.jpg' -> '/content/images/images/Bengal_103.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_176.jpg' -> '/content/images/images/Sphynx_176.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_108.jpg' -> '/content/images/images/staffordshire_bull_terrier_108.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_36.jpg' -> '/content/images/images/Bengal_36.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/chihuahua_136.jpg' -> '/content/images/images/chihuahua_136.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_14.jpg' -> '/content/images/images/beagle_14.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_46.jpg' -> '/content/images/images/Bengal_46.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_6.jpg' -> '/content/images/images/Maine_Coon_6.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_173.jpg' -> '/content/images/images/pug_173.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_94.jpg' -> '/content/images/images/beagle_94.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_83.jpg' -> '/content/images/images/Siamese_83.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Ragdoll_255.jpg' -> '/content/images/images/Ragdoll_255.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_24.jpg' -> '/content/images/images/Maine_Coon_24.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_202.jpg' -> '/content/images/images/pug_202.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/newfoundland_162.jpg' -> '/content/images/images/newfoundland_162.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_4.jpg' -> '/content/images/images/Sphynx_4.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_34.jpg' -> '/content/images/images/samoyed_34.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_86.jpg' -> '/content/images/images/miniature_pinscher_86.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Birman_15.jpg' -> '/content/images/images/Birman_15.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_29.jpg' -> '/content/images/images/german_shorthaired_29.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_108.jpg' -> '/content/images/images/pug_108.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/great_pyrenees_103.jpg' -> '/content/images/images/great_pyrenees_103.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_135.jpg' -> '/content/images/images/american_bulldog_135.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_146.jpg' -> '/content/images/images/Bengal_146.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_1.jpg' -> '/content/images/images/pug_1.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_24.jpg' -> '/content/images/images/saint_bernard_24.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_92.jpg' -> '/content/images/images/beagle_92.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Ragdoll_190.jpg' -> '/content/images/images/Ragdoll_190.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_17.jpg' -> '/content/images/images/samoyed_17.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_101.jpg' -> '/content/images/images/miniature_pinscher_101.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_63.jpg' -> '/content/images/images/Russian_Blue_63.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_129.jpg' -> '/content/images/images/Siamese_129.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Birman_194.jpg' -> '/content/images/images/Birman_194.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_175.jpg' -> '/content/images/images/Abyssinian_175.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_125.jpg' -> '/content/images/images/keeshond_125.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_144.jpg' -> '/content/images/images/havanese_144.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_70.jpg' -> '/content/images/images/pomeranian_70.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_21.jpg' -> '/content/images/images/keeshond_21.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_123.jpg' -> '/content/images/images/american_pit_bull_terrier_123.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_42.jpg' -> '/content/images/images/Bengal_42.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_114.jpg' -> '/content/images/images/shiba_inu_114.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_149.jpg' -> '/content/images/images/yorkshire_terrier_149.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_148.jpg' -> '/content/images/images/english_cocker_spaniel_148.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_166.jpg' -> '/content/images/images/samoyed_166.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_50.jpg' -> '/content/images/images/shiba_inu_50.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_139.jpg' -> '/content/images/images/Abyssinian_139.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_27.jpg' -> '/content/images/images/Egyptian_Mau_27.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_10.jpg' -> '/content/images/images/Maine_Coon_10.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_146.jpg' -> '/content/images/images/american_pit_bull_terrier_146.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_44.jpg' -> '/content/images/images/miniature_pinscher_44.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_48.jpg' -> '/content/images/images/pomeranian_48.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/leonberger_140.jpg' -> '/content/images/images/leonberger_140.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_116.jpg' -> '/content/images/images/staffordshire_bull_terrier_116.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_194.jpg' -> '/content/images/images/basset_hound_194.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_120.jpg' -> '/content/images/images/basset_hound_120.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_190.jpg' -> '/content/images/images/german_shorthaired_190.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_33.jpg' -> '/content/images/images/beagle_33.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_40.jpg' -> '/content/images/images/yorkshire_terrier_40.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_77.jpg' -> '/content/images/images/boxer_77.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_127.jpg' -> '/content/images/images/english_cocker_spaniel_127.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_80.jpg' -> '/content/images/images/saint_bernard_80.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_135.jpg' -> '/content/images/images/Siamese_135.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/newfoundland_195.jpg' -> '/content/images/images/newfoundland_195.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_158.jpg' -> '/content/images/images/scottish_terrier_158.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_99.jpg' -> '/content/images/images/Sphynx_99.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/leonberger_182.jpg' -> '/content/images/images/leonberger_182.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Persian_69.jpg' -> '/content/images/images/Persian_69.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_184.jpg' -> '/content/images/images/Sphynx_184.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_29.jpg' -> '/content/images/images/Russian_Blue_29.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_58.jpg' -> '/content/images/images/Bombay_58.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/great_pyrenees_93.jpg' -> '/content/images/images/great_pyrenees_93.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/chihuahua_112.jpg' -> '/content/images/images/chihuahua_112.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_95.jpg' -> '/content/images/images/pomeranian_95.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_124.jpg' -> '/content/images/images/Bengal_124.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_180.jpg' -> '/content/images/images/saint_bernard_180.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_5.jpg' -> '/content/images/images/keeshond_5.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/newfoundland_68.jpg' -> '/content/images/images/newfoundland_68.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_119.jpg' -> '/content/images/images/samoyed_119.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_13.jpg' -> '/content/images/images/havanese_13.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_23.jpg' -> '/content/images/images/Siamese_23.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_76.jpg' -> '/content/images/images/saint_bernard_76.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_44.jpg' -> '/content/images/images/saint_bernard_44.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Birman_30.jpg' -> '/content/images/images/Birman_30.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_6.jpg' -> '/content/images/images/wheaten_terrier_6.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_140.jpg' -> '/content/images/images/Abyssinian_140.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_179.jpg' -> '/content/images/images/japanese_chin_179.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_36.jpg' -> '/content/images/images/german_shorthaired_36.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/leonberger_48.jpg' -> '/content/images/images/leonberger_48.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_119.jpg' -> '/content/images/images/Russian_Blue_119.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_99.jpg' -> '/content/images/images/havanese_99.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_194.jpg' -> '/content/images/images/Bombay_194.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Birman_112.jpg' -> '/content/images/images/Birman_112.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_7.jpg' -> '/content/images/images/basset_hound_7.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_26.jpg' -> '/content/images/images/havanese_26.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/newfoundland_104.jpg' -> '/content/images/images/newfoundland_104.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_3.jpg' -> '/content/images/images/pomeranian_3.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_98.jpg' -> '/content/images/images/pug_98.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_3.jpg' -> '/content/images/images/Maine_Coon_3.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/chihuahua_200.jpg' -> '/content/images/images/chihuahua_200.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_158.jpg' -> '/content/images/images/beagle_158.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_224.jpg' -> '/content/images/images/Egyptian_Mau_224.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_12.jpg' -> '/content/images/images/pomeranian_12.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_31.jpg' -> '/content/images/images/Abyssinian_31.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_83.jpg' -> '/content/images/images/British_Shorthair_83.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_32.jpg' -> '/content/images/images/boxer_32.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_123.jpg' -> '/content/images/images/beagle_123.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_174.jpg' -> '/content/images/images/yorkshire_terrier_174.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_129.jpg' -> '/content/images/images/german_shorthaired_129.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_93.jpg' -> '/content/images/images/scottish_terrier_93.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_38.jpg' -> '/content/images/images/beagle_38.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_187.jpg' -> '/content/images/images/pomeranian_187.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_90.jpg' -> '/content/images/images/japanese_chin_90.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_107.jpg' -> '/content/images/images/samoyed_107.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_5.jpg' -> '/content/images/images/german_shorthaired_5.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_141.jpg' -> '/content/images/images/miniature_pinscher_141.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_263.jpg' -> '/content/images/images/Russian_Blue_263.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_213.jpg' -> '/content/images/images/British_Shorthair_213.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_124.jpg' -> '/content/images/images/staffordshire_bull_terrier_124.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_181.jpg' -> '/content/images/images/Egyptian_Mau_181.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Persian_56.jpg' -> '/content/images/images/Persian_56.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_162.jpg' -> '/content/images/images/British_Shorthair_162.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_167.jpg' -> '/content/images/images/beagle_167.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_137.jpg' -> '/content/images/images/pug_137.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_145.jpg' -> '/content/images/images/boxer_145.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_177.jpg' -> '/content/images/images/pomeranian_177.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/great_pyrenees_107.jpg' -> '/content/images/images/great_pyrenees_107.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Birman_184.jpg' -> '/content/images/images/Birman_184.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_74.jpg' -> '/content/images/images/american_pit_bull_terrier_74.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_159.jpg' -> '/content/images/images/Russian_Blue_159.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_159.jpg' -> '/content/images/images/havanese_159.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_69.jpg' -> '/content/images/images/pug_69.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_33.jpg' -> '/content/images/images/Sphynx_33.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_118.jpg' -> '/content/images/images/beagle_118.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/great_pyrenees_170.jpg' -> '/content/images/images/great_pyrenees_170.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_140.jpg' -> '/content/images/images/Russian_Blue_140.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_125.jpg' -> '/content/images/images/Bombay_125.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_173.jpg' -> '/content/images/images/saint_bernard_173.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Ragdoll_138.jpg' -> '/content/images/images/Ragdoll_138.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_setter_183.jpg' -> '/content/images/images/english_setter_183.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_103.jpg' -> '/content/images/images/Bombay_103.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_30.jpg' -> '/content/images/images/english_cocker_spaniel_30.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_11.jpg' -> '/content/images/images/Sphynx_11.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_42.jpg' -> '/content/images/images/staffordshire_bull_terrier_42.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_129.jpg' -> '/content/images/images/american_pit_bull_terrier_129.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_186.jpg' -> '/content/images/images/keeshond_186.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_174.jpg' -> '/content/images/images/pug_174.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/newfoundland_120.jpg' -> '/content/images/images/newfoundland_120.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_64.jpg' -> '/content/images/images/Russian_Blue_64.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_102.jpg' -> '/content/images/images/beagle_102.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Ragdoll_152.jpg' -> '/content/images/images/Ragdoll_152.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_105.jpg' -> '/content/images/images/British_Shorthair_105.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_181.jpg' -> '/content/images/images/beagle_181.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_36.jpg' -> '/content/images/images/Abyssinian_36.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_142.jpg' -> '/content/images/images/american_pit_bull_terrier_142.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_186.jpg' -> '/content/images/images/Siamese_186.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_76.jpg' -> '/content/images/images/samoyed_76.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_145.jpg' -> '/content/images/images/Sphynx_145.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_113.jpg' -> '/content/images/images/scottish_terrier_113.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_200.jpg' -> '/content/images/images/saint_bernard_200.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_setter_147.jpg' -> '/content/images/images/english_setter_147.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/newfoundland_135.jpg' -> '/content/images/images/newfoundland_135.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_139.jpg' -> '/content/images/images/Bengal_139.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_59.jpg' -> '/content/images/images/american_pit_bull_terrier_59.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_21.jpg' -> '/content/images/images/Siamese_21.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_44.jpg' -> '/content/images/images/pug_44.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/chihuahua_148.jpg' -> '/content/images/images/chihuahua_148.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_153.jpg' -> '/content/images/images/american_pit_bull_terrier_153.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_173.jpg' -> '/content/images/images/english_cocker_spaniel_173.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_200.jpg' -> '/content/images/images/Bombay_200.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Persian_10.jpg' -> '/content/images/images/Persian_10.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_130.jpg' -> '/content/images/images/Bombay_130.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_42.jpg' -> '/content/images/images/keeshond_42.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_160.jpg' -> '/content/images/images/english_cocker_spaniel_160.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_50.jpg' -> '/content/images/images/pomeranian_50.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_16.jpg' -> '/content/images/images/Maine_Coon_16.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_73.jpg' -> '/content/images/images/keeshond_73.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_148.jpg' -> '/content/images/images/pug_148.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_169.jpg' -> '/content/images/images/pug_169.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_175.jpg' -> '/content/images/images/boxer_175.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_212.jpg' -> '/content/images/images/Russian_Blue_212.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_38.jpg' -> '/content/images/images/Maine_Coon_38.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_55.jpg' -> '/content/images/images/german_shorthaired_55.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_49.jpg' -> '/content/images/images/german_shorthaired_49.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_26.jpg' -> '/content/images/images/keeshond_26.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_140.jpg' -> '/content/images/images/english_cocker_spaniel_140.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Ragdoll_136.jpg' -> '/content/images/images/Ragdoll_136.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_99.jpg' -> '/content/images/images/scottish_terrier_99.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_21.jpg' -> '/content/images/images/german_shorthaired_21.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_269.jpg' -> '/content/images/images/British_Shorthair_269.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_18.jpg' -> '/content/images/images/yorkshire_terrier_18.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_143.jpg' -> '/content/images/images/english_cocker_spaniel_143.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_setter_59.jpg' -> '/content/images/images/english_setter_59.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_216.jpg' -> '/content/images/images/Russian_Blue_216.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_147.jpg' -> '/content/images/images/Egyptian_Mau_147.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_85.jpg' -> '/content/images/images/japanese_chin_85.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_196.jpg' -> '/content/images/images/japanese_chin_196.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_187.jpg' -> '/content/images/images/saint_bernard_187.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_40.jpg' -> '/content/images/images/Siamese_40.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_81.jpg' -> '/content/images/images/Egyptian_Mau_81.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_114.jpg' -> '/content/images/images/beagle_114.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_142.jpg' -> '/content/images/images/Siamese_142.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/chihuahua_143.jpg' -> '/content/images/images/chihuahua_143.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_209.jpg' -> '/content/images/images/Siamese_209.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_76.jpg' -> '/content/images/images/english_cocker_spaniel_76.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_185.jpg' -> '/content/images/images/Egyptian_Mau_185.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_34.jpg' -> '/content/images/images/Bengal_34.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_201.jpg' -> '/content/images/images/Russian_Blue_201.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_139.jpg' -> '/content/images/images/shiba_inu_139.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_20.jpg' -> '/content/images/images/basset_hound_20.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Ragdoll_164.jpg' -> '/content/images/images/Ragdoll_164.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_109.jpg' -> '/content/images/images/german_shorthaired_109.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/great_pyrenees_1.jpg' -> '/content/images/images/great_pyrenees_1.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Persian_45.jpg' -> '/content/images/images/Persian_45.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_138.jpg' -> '/content/images/images/american_bulldog_138.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_79.jpg' -> '/content/images/images/wheaten_terrier_79.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_133.jpg' -> '/content/images/images/shiba_inu_133.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_176.jpg' -> '/content/images/images/miniature_pinscher_176.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_47.jpg' -> '/content/images/images/yorkshire_terrier_47.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_159.jpg' -> '/content/images/images/Abyssinian_159.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_40.jpg' -> '/content/images/images/boxer_40.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_64.jpg' -> '/content/images/images/samoyed_64.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_138.jpg' -> '/content/images/images/boxer_138.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_21.jpg' -> '/content/images/images/Abyssinian_21.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/newfoundland_175.jpg' -> '/content/images/images/newfoundland_175.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/chihuahua_63.jpg' -> '/content/images/images/chihuahua_63.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_178.jpg' -> '/content/images/images/american_bulldog_178.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_183.jpg' -> '/content/images/images/basset_hound_183.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_78.jpg' -> '/content/images/images/Bengal_78.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_104.jpg' -> '/content/images/images/staffordshire_bull_terrier_104.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/newfoundland_101.jpg' -> '/content/images/images/newfoundland_101.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/great_pyrenees_110.jpg' -> '/content/images/images/great_pyrenees_110.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_127.jpg' -> '/content/images/images/yorkshire_terrier_127.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_12.jpg' -> '/content/images/images/saint_bernard_12.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_21.jpg' -> '/content/images/images/Sphynx_21.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_45.jpg' -> '/content/images/images/saint_bernard_45.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_117.jpg' -> '/content/images/images/samoyed_117.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/leonberger_167.jpg' -> '/content/images/images/leonberger_167.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_134.jpg' -> '/content/images/images/beagle_134.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_21.jpg' -> '/content/images/images/havanese_21.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_8.jpg' -> '/content/images/images/boxer_8.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_82.jpg' -> '/content/images/images/pomeranian_82.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_177.jpg' -> '/content/images/images/boxer_177.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_132.jpg' -> '/content/images/images/Maine_Coon_132.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_137.jpg' -> '/content/images/images/Bengal_137.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_133.jpg' -> '/content/images/images/american_bulldog_133.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_102.jpg' -> '/content/images/images/Egyptian_Mau_102.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Birman_92.jpg' -> '/content/images/images/Birman_92.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Persian_202.jpg' -> '/content/images/images/Persian_202.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_setter_168.jpg' -> '/content/images/images/english_setter_168.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_73.jpg' -> '/content/images/images/staffordshire_bull_terrier_73.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_26.jpg' -> '/content/images/images/english_cocker_spaniel_26.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_191.jpg' -> '/content/images/images/pomeranian_191.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_185.jpg' -> '/content/images/images/pug_185.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_144.jpg' -> '/content/images/images/Russian_Blue_144.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/leonberger_169.jpg' -> '/content/images/images/leonberger_169.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_60.jpg' -> '/content/images/images/wheaten_terrier_60.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_191.jpg' -> '/content/images/images/keeshond_191.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_115.jpg' -> '/content/images/images/japanese_chin_115.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_184.jpg' -> '/content/images/images/Bengal_184.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_50.jpg' -> '/content/images/images/american_pit_bull_terrier_50.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_92.jpg' -> '/content/images/images/basset_hound_92.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_134.jpg' -> '/content/images/images/miniature_pinscher_134.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_57.jpg' -> '/content/images/images/Bengal_57.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_83.jpg' -> '/content/images/images/samoyed_83.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_18.jpg' -> '/content/images/images/Abyssinian_18.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_69.jpg' -> '/content/images/images/miniature_pinscher_69.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_115.jpg' -> '/content/images/images/beagle_115.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_181.jpg' -> '/content/images/images/keeshond_181.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_16.jpg' -> '/content/images/images/yorkshire_terrier_16.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/great_pyrenees_53.jpg' -> '/content/images/images/great_pyrenees_53.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_81.jpg' -> '/content/images/images/boxer_81.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/chihuahua_177.jpg' -> '/content/images/images/chihuahua_177.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_100.jpg' -> '/content/images/images/american_pit_bull_terrier_100.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_190.jpg' -> '/content/images/images/yorkshire_terrier_190.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_37.jpg' -> '/content/images/images/keeshond_37.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_28.jpg' -> '/content/images/images/boxer_28.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_7.jpg' -> '/content/images/images/staffordshire_bull_terrier_7.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_205.jpg' -> '/content/images/images/Siamese_205.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_187.jpg' -> '/content/images/images/samoyed_187.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_60.jpg' -> '/content/images/images/Abyssinian_60.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_35.jpg' -> '/content/images/images/wheaten_terrier_35.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_3.jpg' -> '/content/images/images/yorkshire_terrier_3.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_setter_170.jpg' -> '/content/images/images/english_setter_170.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_101.jpg' -> '/content/images/images/wheaten_terrier_101.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_204.jpg' -> '/content/images/images/Russian_Blue_204.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_67.jpg' -> '/content/images/images/american_pit_bull_terrier_67.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_80.jpg' -> '/content/images/images/Siamese_80.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_158.jpg' -> '/content/images/images/Bengal_158.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_193.jpg' -> '/content/images/images/Bombay_193.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Birman_2.jpg' -> '/content/images/images/Birman_2.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_69.jpg' -> '/content/images/images/Maine_Coon_69.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_199.jpg' -> '/content/images/images/american_pit_bull_terrier_199.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_73.jpg' -> '/content/images/images/american_pit_bull_terrier_73.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_10.jpg' -> '/content/images/images/Egyptian_Mau_10.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_8.jpg' -> '/content/images/images/pug_8.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_154.jpg' -> '/content/images/images/pomeranian_154.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Ragdoll_116.jpg' -> '/content/images/images/Ragdoll_116.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/chihuahua_197.jpg' -> '/content/images/images/chihuahua_197.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_47.jpg' -> '/content/images/images/beagle_47.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_30.jpg' -> '/content/images/images/keeshond_30.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_48.jpg' -> '/content/images/images/samoyed_48.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_185.jpg' -> '/content/images/images/staffordshire_bull_terrier_185.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_159.jpg' -> '/content/images/images/pomeranian_159.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_72.jpg' -> '/content/images/images/scottish_terrier_72.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/leonberger_64.jpg' -> '/content/images/images/leonberger_64.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_185.jpg' -> '/content/images/images/yorkshire_terrier_185.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_141.jpg' -> '/content/images/images/pug_141.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_63.jpg' -> '/content/images/images/scottish_terrier_63.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_270.jpg' -> '/content/images/images/Maine_Coon_270.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_194.jpg' -> '/content/images/images/samoyed_194.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_161.jpg' -> '/content/images/images/scottish_terrier_161.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_136.jpg' -> '/content/images/images/keeshond_136.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Birman_60.jpg' -> '/content/images/images/Birman_60.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_19.jpg' -> '/content/images/images/samoyed_19.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_113.jpg' -> '/content/images/images/wheaten_terrier_113.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_138.jpg' -> '/content/images/images/Abyssinian_138.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Birman_193.jpg' -> '/content/images/images/Birman_193.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_95.jpg' -> '/content/images/images/Siamese_95.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_80.jpg' -> '/content/images/images/basset_hound_80.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_10.jpg' -> '/content/images/images/japanese_chin_10.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_24.jpg' -> '/content/images/images/wheaten_terrier_24.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_36.jpg' -> '/content/images/images/Egyptian_Mau_36.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_65.jpg' -> '/content/images/images/keeshond_65.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_112.jpg' -> '/content/images/images/yorkshire_terrier_112.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_175.jpg' -> '/content/images/images/Siamese_175.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_161.jpg' -> '/content/images/images/japanese_chin_161.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_132.jpg' -> '/content/images/images/pug_132.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_185.jpg' -> '/content/images/images/British_Shorthair_185.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_138.jpg' -> '/content/images/images/basset_hound_138.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_194.jpg' -> '/content/images/images/boxer_194.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_197.jpg' -> '/content/images/images/miniature_pinscher_197.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_165.jpg' -> '/content/images/images/staffordshire_bull_terrier_165.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_162.jpg' -> '/content/images/images/samoyed_162.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_137.jpg' -> '/content/images/images/miniature_pinscher_137.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_14.jpg' -> '/content/images/images/staffordshire_bull_terrier_14.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_17.jpg' -> '/content/images/images/pomeranian_17.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_2.jpg' -> '/content/images/images/Sphynx_2.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_200.jpg' -> '/content/images/images/boxer_200.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_109.jpg' -> '/content/images/images/shiba_inu_109.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_189.jpg' -> '/content/images/images/Siamese_189.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/chihuahua_85.jpg' -> '/content/images/images/chihuahua_85.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_169.jpg' -> '/content/images/images/staffordshire_bull_terrier_169.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_42.jpg' -> '/content/images/images/Egyptian_Mau_42.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_272.jpg' -> '/content/images/images/Maine_Coon_272.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_34.jpg' -> '/content/images/images/english_cocker_spaniel_34.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_25.jpg' -> '/content/images/images/keeshond_25.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_19.jpg' -> '/content/images/images/american_bulldog_19.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_1.jpg' -> '/content/images/images/german_shorthaired_1.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_64.jpg' -> '/content/images/images/american_pit_bull_terrier_64.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_58.jpg' -> '/content/images/images/yorkshire_terrier_58.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_23.jpg' -> '/content/images/images/samoyed_23.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_26.jpg' -> '/content/images/images/pomeranian_26.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_63.jpg' -> '/content/images/images/Egyptian_Mau_63.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_56.jpg' -> '/content/images/images/pug_56.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_146.jpg' -> '/content/images/images/shiba_inu_146.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_4.jpg' -> '/content/images/images/american_pit_bull_terrier_4.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_12.jpg' -> '/content/images/images/shiba_inu_12.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_198.jpg' -> '/content/images/images/Bombay_198.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_21.jpg' -> '/content/images/images/pug_21.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_223.jpg' -> '/content/images/images/Abyssinian_223.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_41.jpg' -> '/content/images/images/english_cocker_spaniel_41.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_213.jpg' -> '/content/images/images/Bombay_213.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_40.jpg' -> '/content/images/images/wheaten_terrier_40.jpg'
# ...
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_62.jpg' -> '/content/images/images/samoyed_62.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_49.jpg' -> '/content/images/images/Russian_Blue_49.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_189.jpg' -> '/content/images/images/pug_189.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_204.jpg' -> '/content/images/images/Siamese_204.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_48.jpg' -> '/content/images/images/scottish_terrier_48.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_130.jpg' -> '/content/images/images/german_shorthaired_130.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_37.jpg' -> '/content/images/images/american_bulldog_37.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_100.jpg' -> '/content/images/images/havanese_100.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_92.jpg' -> '/content/images/images/British_Shorthair_92.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_158.jpg' -> '/content/images/images/Sphynx_158.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_131.jpg' -> '/content/images/images/Abyssinian_131.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_69.jpg' -> '/content/images/images/german_shorthaired_69.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_101.jpg' -> '/content/images/images/Egyptian_Mau_101.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_setter_125.jpg' -> '/content/images/images/english_setter_125.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/great_pyrenees_174.jpg' -> '/content/images/images/great_pyrenees_174.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_103.jpg' -> '/content/images/images/havanese_103.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_109.jpg' -> '/content/images/images/samoyed_109.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/great_pyrenees_151.jpg' -> '/content/images/images/great_pyrenees_151.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_42.jpg' -> '/content/images/images/shiba_inu_42.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_109.jpg' -> '/content/images/images/pug_109.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_210.jpg' -> '/content/images/images/British_Shorthair_210.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/chihuahua_61.jpg' -> '/content/images/images/chihuahua_61.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_94.jpg' -> '/content/images/images/Maine_Coon_94.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_30.jpg' -> '/content/images/images/samoyed_30.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_143.jpg' -> '/content/images/images/japanese_chin_143.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_194.jpg' -> '/content/images/images/keeshond_194.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_9.jpg' -> '/content/images/images/Russian_Blue_9.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_142.jpg' -> '/content/images/images/english_cocker_spaniel_142.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_170.jpg' -> '/content/images/images/pug_170.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_127.jpg' -> '/content/images/images/german_shorthaired_127.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_154.jpg' -> '/content/images/images/havanese_154.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_70.jpg' -> '/content/images/images/keeshond_70.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_168.jpg' -> '/content/images/images/Maine_Coon_168.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_40.jpg' -> '/content/images/images/Abyssinian_40.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_111.jpg' -> '/content/images/images/american_bulldog_111.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_176.jpg' -> '/content/images/images/american_pit_bull_terrier_176.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_128.jpg' -> '/content/images/images/Siamese_128.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_107.jpg' -> '/content/images/images/Bombay_107.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_82.jpg' -> '/content/images/images/keeshond_82.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_7.jpg' -> '/content/images/images/beagle_7.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_200.jpg' -> '/content/images/images/beagle_200.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/great_pyrenees_77.jpg' -> '/content/images/images/great_pyrenees_77.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_72.jpg' -> '/content/images/images/wheaten_terrier_72.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_231.jpg' -> '/content/images/images/Maine_Coon_231.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_241.jpg' -> '/content/images/images/British_Shorthair_241.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Persian_183.jpg' -> '/content/images/images/Persian_183.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_67.jpg' -> '/content/images/images/scottish_terrier_67.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_173.jpg' -> '/content/images/images/Bombay_173.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_8.jpg' -> '/content/images/images/Abyssinian_8.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/leonberger_98.jpg' -> '/content/images/images/leonberger_98.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_101.jpg' -> '/content/images/images/japanese_chin_101.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_14.jpg' -> '/content/images/images/Bombay_14.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_209.jpg' -> '/content/images/images/american_bulldog_209.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_124.jpg' -> '/content/images/images/beagle_124.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_73.jpg' -> '/content/images/images/basset_hound_73.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_192.jpg' -> '/content/images/images/keeshond_192.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_105.jpg' -> '/content/images/images/Maine_Coon_105.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_204.jpg' -> '/content/images/images/Sphynx_204.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_106.jpg' -> '/content/images/images/Maine_Coon_106.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_17.jpg' -> '/content/images/images/Maine_Coon_17.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_31.jpg' -> '/content/images/images/samoyed_31.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_118.jpg' -> '/content/images/images/staffordshire_bull_terrier_118.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_87.jpg' -> '/content/images/images/havanese_87.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_133.jpg' -> '/content/images/images/Sphynx_133.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_170.jpg' -> '/content/images/images/Sphynx_170.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_100.jpg' -> '/content/images/images/British_Shorthair_100.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_69.jpg' -> '/content/images/images/english_cocker_spaniel_69.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_48.jpg' -> '/content/images/images/Siamese_48.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_182.jpg' -> '/content/images/images/boxer_182.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_207.jpg' -> '/content/images/images/american_bulldog_207.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_45.jpg' -> '/content/images/images/havanese_45.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pug_122.jpg' -> '/content/images/images/pug_122.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_110.jpg' -> '/content/images/images/miniature_pinscher_110.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Ragdoll_257.jpg' -> '/content/images/images/Ragdoll_257.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_123.jpg' -> '/content/images/images/Abyssinian_123.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Maine_Coon_205.jpg' -> '/content/images/images/Maine_Coon_205.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_9.jpg' -> '/content/images/images/staffordshire_bull_terrier_9.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_146.jpg' -> '/content/images/images/wheaten_terrier_146.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_86.jpg' -> '/content/images/images/British_Shorthair_86.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_70.jpg' -> '/content/images/images/Russian_Blue_70.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_158.jpg' -> '/content/images/images/havanese_158.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_163.jpg' -> '/content/images/images/english_cocker_spaniel_163.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_143.jpg' -> '/content/images/images/Russian_Blue_143.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_120.jpg' -> '/content/images/images/scottish_terrier_120.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Birman_59.jpg' -> '/content/images/images/Birman_59.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_75.jpg' -> '/content/images/images/Abyssinian_75.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_71.jpg' -> '/content/images/images/Sphynx_71.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_15.jpg' -> '/content/images/images/shiba_inu_15.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bengal_172.jpg' -> '/content/images/images/Bengal_172.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/havanese_126.jpg' -> '/content/images/images/havanese_126.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_122.jpg' -> '/content/images/images/staffordshire_bull_terrier_122.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_42.jpg' -> '/content/images/images/american_pit_bull_terrier_42.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_170.jpg' -> '/content/images/images/beagle_170.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_38.jpg' -> '/content/images/images/boxer_38.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_141.jpg' -> '/content/images/images/english_cocker_spaniel_141.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_1.jpg' -> '/content/images/images/miniature_pinscher_1.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_163.jpg' -> '/content/images/images/scottish_terrier_163.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_88.jpg' -> '/content/images/images/basset_hound_88.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/leonberger_128.jpg' -> '/content/images/images/leonberger_128.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_95.jpg' -> '/content/images/images/miniature_pinscher_95.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_24.jpg' -> '/content/images/images/yorkshire_terrier_24.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_5.jpg' -> '/content/images/images/wheaten_terrier_5.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/newfoundland_148.jpg' -> '/content/images/images/newfoundland_148.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_182.jpg' -> '/content/images/images/american_pit_bull_terrier_182.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_2.jpg' -> '/content/images/images/Abyssinian_2.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_59.jpg' -> '/content/images/images/keeshond_59.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/scottish_terrier_21.jpg' -> '/content/images/images/scottish_terrier_21.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_164.jpg' -> '/content/images/images/german_shorthaired_164.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_85.jpg' -> '/content/images/images/Bombay_85.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_4.jpg' -> '/content/images/images/japanese_chin_4.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/boxer_82.jpg' -> '/content/images/images/boxer_82.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_173.jpg' -> '/content/images/images/samoyed_173.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Bombay_127.jpg' -> '/content/images/images/Bombay_127.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_98.jpg' -> '/content/images/images/basset_hound_98.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/basset_hound_190.jpg' -> '/content/images/images/basset_hound_190.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Sphynx_37.jpg' -> '/content/images/images/Sphynx_37.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_48.jpg' -> '/content/images/images/wheaten_terrier_48.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Russian_Blue_175.jpg' -> '/content/images/images/Russian_Blue_175.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_85.jpg' -> '/content/images/images/staffordshire_bull_terrier_85.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_158.jpg' -> '/content/images/images/Abyssinian_158.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_68.jpg' -> '/content/images/images/British_Shorthair_68.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_114.jpg' -> '/content/images/images/pomeranian_114.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/keeshond_115.jpg' -> '/content/images/images/keeshond_115.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Siamese_127.jpg' -> '/content/images/images/Siamese_127.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Abyssinian_33.jpg' -> '/content/images/images/Abyssinian_33.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/samoyed_141.jpg' -> '/content/images/images/samoyed_141.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/saint_bernard_89.jpg' -> '/content/images/images/saint_bernard_89.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_121.jpg' -> '/content/images/images/american_bulldog_121.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_186.jpg' -> '/content/images/images/staffordshire_bull_terrier_186.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Persian_86.jpg' -> '/content/images/images/Persian_86.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_138.jpg' -> '/content/images/images/staffordshire_bull_terrier_138.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_88.jpg' -> '/content/images/images/pomeranian_88.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/chihuahua_144.jpg' -> '/content/images/images/chihuahua_144.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_5.jpg' -> '/content/images/images/Egyptian_Mau_5.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/Persian_21.jpg' -> '/content/images/images/Persian_21.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_20.jpg' -> '/content/images/images/american_bulldog_20.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/beagle_120.jpg' -> '/content/images/images/beagle_120.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/pomeranian_10.jpg' -> '/content/images/images/pomeranian_10.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/newfoundland_61.jpg' -> '/content/images/images/newfoundland_61.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/British_Shorthair_21.jpg' -> '/content/images/images/British_Shorthair_21.jpg'
# '/root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_151.jpg' -> '/content/images/images/german_shorthaired_151.jpg'

# %%
#id first_training
#caption Results from the first training
# CLICK ME
from fastai.vision.all import *
path = untar_data(URLs.PETS)/'images'

def is_cat(x): return x[0].isupper()

dls = ImageDataLoaders.from_name_func(
    path, get_image_files(path), valid_pct=0.2, seed=42,
    label_func=is_cat, item_tfms=Resize(224))

learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.168271</td>
#       <td>0.045281</td>
#       <td>0.011502</td>
#       <td>01:36</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.044908</td>
#       <td>0.020710</td>
#       <td>0.006766</td>
#       <td>02:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fine_tune?

# %% [markdown]
# You will probably not see exactly the same results that are in the session. There are a lot of sources of small random variation involved in training models. We generally see an error rate of well less than 0.02 in this example, however.

# %% [markdown]
# > important: Training Time: Depending on your network speed, it might take a few minutes to download the pretrained model and dataset. Running `fine_tune` might take a minute or so. Often models take a few minutes to train, as will your own models, so it's a good idea to come up with good techniques to make the most of this time. For instance, keep reading the next section while your model trains, or open up another notebook and use it for some coding experiments.

# %% [markdown]
# ### Sidebar: Lets dive into Jupyter Notebook

# %% [markdown]
# We wrote this notebook using Jupyter notebooks, so for nearly every chart, table, and calculation in this notebook, we'll be showing you the exact code required to replicate it yourself.

# %% [markdown]
# You just saw how a cell that outputs a table looks
#
# ```
# # This is formatted as code
# ```
#
# . Here is an example of a cell that outputs text:

# %%
1+1
# Out:
# 2

# %%
# !pwd
# Out:
# /content/DL-Workshop-1

# %%
# !ls
# Out:
# 01__intro.ipynb  images  Rock  theRock

# %% [markdown]
# Jupyter will always print or show the result of the last line (if there is one). For instance, here is an example of a cell that outputs an image:

# %%
image_cat??

# %%
img = PILImage.create(image_cat())
img.to_thumb(192)
# Out:
# <PIL.Image.Image image mode=RGB size=151x192 at 0x7FCBC96B7910>

# %% [markdown]
# Finally, let's check that this model actually works. Go and get a photo of a dog, or a cat; if you don't have one handy, just search Google Images and download an image that you find there. Now execute the cell with `uploader` defined. It will output a button you can click, so you can select the image you want to classify:

# %%
#hide_output
uploader = widgets.FileUpload()
uploader
# Out:
# FileUpload(value={}, description='Upload')

# %% [markdown]
# Now you can pass the uploaded file to the model. Make sure that it is a clear photo of a single dog or a cat, and not a line drawing, cartoon, or similar. The notebook will tell you whether it thinks it is a dog or a cat, and how confident it is. Hopefully, you'll find that your model did a great job:

# %%
img = PILImage.create(uploader.data[0])
is_cat,_,probs = learn.predict(img)
print(f"Is this a cat?: {is_cat}.")
print(f"Probability it's a cat: {probs[1].item():.6f}")
# Out:
# Is this a cat?: True.
# Probability it's a cat: 1.000000

# %% [markdown]
# Congratulations on your first classifier!
#
# But what does this mean? What did you actually do? In order to explain this, let's zoom out again to take in the big picture.

# %% [markdown]
# ### What Is Machine Learning?

# %% [markdown]
# Your classifier is a deep learning model. As was already mentioned, deep learning models use neural networks, which originally date from the 1950s and have become powerful very recently thanks to recent advancements.
#
# Another key piece of context is that deep learning is just a modern area in the more general discipline of *machine learning*. To understand the essence of what you did when you trained your own classification model, you don't need to understand deep learning. It is enough to see how your model and your training process are examples of the concepts that apply to machine learning in general.
#
# So in this section, we will describe what machine learning is. We will look at the key concepts, and show how they can be traced back to the original essay that introduced them.
#
# *Machine learning* is, like regular programming, a way to get computers to complete a specific task. But how would we use regular programming to do what we just did in the last section: recognize dogs versus cats in photos? We would have to write down for the computer the exact steps necessary to complete the task.
#
# Normally, it's easy enough for us to write down the steps to complete a task when we're writing a program. We just think about the steps we'd take if we had to do the task by hand, and then we translate them into code. For instance, we can write a function that sorts a list. In general, we'd write a function that looks something like <<basic_program>> (where *inputs* might be an unsorted list, and *results* a sorted list).

# %%
#hide_input
#caption A traditional program
#id basic_program
#alt Pipeline inputs, program, results
gv('''program[shape=box3d width=1 height=0.7]
inputs->program->results''')

# %% [markdown]
# But for recognizing objects in a photo that's a bit tricky; what *are* the steps we take when we recognize an object in a picture? We really don't know, since it all happens in our brain without us being consciously aware of it!
#
# Right back at the dawn of computing, in 1949, an IBM researcher named Arthur Samuel started working on a different way to get computers to complete tasks, which he called *machine learning*. In his classic 1962 essay "Artificial Intelligence: A Frontier of Automation", he wrote:

# %% [markdown]
# > : Programming a computer for such computations is, at best, a difficult task, not primarily because of any inherent complexity in the computer itself but, rather, because of the need to spell out every minute step of the process in the most exasperating detail. Computers, as any programmer will tell you, are giant morons, not giant brains.

# %% [markdown]
# His basic idea was this: instead of telling the computer the exact steps required to solve a problem, show it examples of the problem to solve, and let it figure out how to solve it itself. This turned out to be very effective: by 1961 his checkers-playing program had learned so much that it beat the Connecticut state champion! Here's how he described his idea (from the same essay as above):

# %% [markdown]
# > : Suppose we arrange for some automatic means of testing the effectiveness of any current weight assignment in terms of actual performance and provide a mechanism for altering the weight assignment so as to maximize the performance. We need not go into the details of such a procedure to see that it could be made entirely automatic and to see that a machine so programmed would "learn" from its experience.

# %% [markdown]
# There are a number of powerful concepts embedded in this short statement:
#
# - The idea of a "weight assignment"
# - The fact that every weight assignment has some "actual performance"
# - The requirement that there be an "automatic means" of testing that performance,
# - The need for a "mechanism" (i.e., another automatic process) for improving the performance by changing the weight assignments
#
# Let us take these concepts one by one, in order to understand how they fit together in practice. First, we need to understand what Samuel means by a *weight assignment*.
#
# Weights are just variables, and a weight assignment is a particular choice of values for those variables. The program's inputs are values that it processes in order to produce its results—for instance, taking image pixels as inputs, and returning the classification "dog" as a result. The program's weight assignments are other values that define how the program will operate.
#
# Since they will affect the program they are in a sense another kind of input, so we will update our basic picture in <<basic_program>> and replace it with <<weight_assignment>> in order to take this into account.

# %%
#hide_input
#caption A program using weight assignment
#id weight_assignment
gv('''model[shape=box3d width=1 height=0.7]
inputs->model->results; weights->model''')

# %% [markdown]
# We've changed the name of our box from *program* to *model*. This is to follow modern terminology and to reflect that the *model* is a special kind of program: it's one that can do *many different things*, depending on the *weights*. It can be implemented in many different ways. For instance, in Samuel's checkers program, different values of the weights would result in different checkers-playing strategies.
#
# (By the way, what Samuel called "weights" are most generally referred to as model *parameters* these days, in case you have encountered that term. The term *weights* is reserved for a particular type of model parameter.)
#
# Next, Samuel said we need an *automatic means of testing the effectiveness of any current weight assignment in terms of actual performance*. In the case of his checkers program, the "actual performance" of a model would be how well it plays. And you could automatically test the performance of two models by setting them to play against each other, and seeing which one usually wins.
#
# Finally, he says we need *a mechanism for altering the weight assignment so as to maximize the performance*. For instance, we could look at the difference in weights between the winning model and the losing model, and adjust the weights a little further in the winning direction.
#
# We can now see why he said that such a procedure *could be made entirely automatic and... a machine so programmed would "learn" from its experience*. Learning would become entirely automatic when the adjustment of the weights was also automatic—when instead of us improving a model by adjusting its weights manually, we relied on an automated mechanism that produced adjustments based on performance.
#
# <<training_loop>> shows the full picture of Samuel's idea of training a machine learning model.

# %%
#hide_input
#caption Training a machine learning model
#id training_loop
#alt The basic training loop
gv('''ordering=in
model[shape=box3d width=1 height=0.7]
inputs->model->results; weights->model; results->performance
performance->weights[constraint=false label=update]''')

# %% [markdown]
# Notice the distinction between the model's *results*  (e.g., the moves in a checkers game) and its *performance* (e.g., whether it wins the game, or how quickly it wins).
#
# Also note that once the model is trained—that is, once we've chosen our final, best, favorite weight assignment—then we can think of the weights as being *part of the model*, since we're not varying them any more.
#
# Therefore, actually *using* a model after it's trained looks like <<using_model>>.

# %%
#hide_input
#caption Using a trained model as a program
#id using_model
gv('''model[shape=box3d width=1 height=0.7]
inputs->model->results''')

# %% [markdown]
# This looks identical to our original diagram in <<basic_program>>, just with the word *program* replaced with *model*. This is an important insight: *a trained model can be treated just like a regular computer program*.

# %% [markdown]
# > jargon: Machine Learning: The training of programs developed by allowing a computer to learn from its experience, rather than through manually coding the individual steps.

# %% [markdown]
# ### What Is a Neural Network?

# %% [markdown]
# It's not too hard to imagine what the model might look like for a checkers program. There might be a range of checkers strategies encoded, and some kind of search mechanism, and then the weights could vary how strategies are selected, what parts of the board are focused on during a search, and so forth. But it's not at all obvious what the model might look like for an image recognition program, or for understanding text, or for many other interesting problems we might imagine.
#
# What we would like is some kind of function that is so flexible that it could be used to solve any given problem, just by varying its weights. Amazingly enough, this function actually exists! It's the neural network, which we already discussed. That is, if you regard a neural network as a mathematical function, it turns out to be a function which is extremely flexible depending on its weights. A mathematical proof called the *universal approximation theorem* shows that this function can solve any problem to any level of accuracy, in theory. The fact that neural networks are so flexible means that, in practice, they are often a suitable kind of model, and you can focus your effort on the process of training them—that is, of finding good weight assignments.
#
# But what about that process?  One could imagine that you might need to find a new "mechanism" for automatically updating weights for every problem. This would be laborious. What we'd like here as well is a completely general way to update the weights of a neural network, to make it improve at any given task. Conveniently, this also exists!
#
# This is called *stochastic gradient descent* (SGD). We'll see how neural networks and SGD work in detail in <<chapter_mnist_basics>>, as well as explaining the universal approximation theorem. For now, however, we will instead use Samuel's own words: *We need not go into the details of such a procedure to see that it could be made entirely automatic and to see that a machine so programmed would "learn" from its experience.*

# %% [markdown]
# A: Don't worry, neither SGD nor neural nets are mathematically complex. Both nearly entirely rely on addition and multiplication to do their work (but they do a _lot_ of addition and multiplication!). The main reaction we hear from students when they see the details is: "Is that **all** it is?"

# %% [markdown]
# In other words, to recap, a neural network is a particular kind of machine learning model, which fits right in to Samuel's original conception. Neural networks are special because they are highly flexible, which means they can solve an unusually wide range of problems just by finding the right weights. This is powerful, because stochastic gradient descent provides us a way to find those weight values automatically.
#
# Having zoomed out, let's now zoom back in and revisit our image classification problem using Samuel's framework.
#
# Our inputs are the images. Our weights are the weights in the neural net. Our model is a neural net. Our results are the values that are calculated by the neural net, like "dog" or "cat."
#
# What about the next piece, an *automatic means of testing the effectiveness of any current weight assignment in terms of actual performance*? Determining "actual performance" is easy enough: we can simply define our model's performance as its accuracy at predicting the correct answers.
#
# Putting this all together, and assuming that SGD is our mechanism for updating the weight assignments, we can see how our image classifier is a machine learning model, much like Samuel envisioned.

# %% [markdown]
# ### A Bit of Deep Learning Jargon

# %% [markdown]
# Samuel was working in the 1960s, and since then terminology has changed. Here is the modern deep learning terminology for all the pieces we have discussed:
#
# - The functional form of the *model* is called its *architecture* (but be careful—sometimes people use *model* as a synonym of *architecture*, so this can get confusing).
# - The *weights* are called *parameters*.
# - The *predictions* are calculated from the *independent variable*, which is the *data* not including the *labels*.
# - The *results* of the model are called *predictions*.
# - The measure of *performance* is called the *loss*.
# - The loss depends not only on the predictions, but also the correct *labels* (also known as *targets* or the *dependent variable*); e.g., "dog" or "cat."
#
# After making these changes, our diagram in <<training_loop>> looks like <<detailed_loop>>.

# %%
#hide_input
#caption Detailed training loop
#id detailed_loop
gv('''ordering=in
model[shape=box3d width=1 height=0.7 label=architecture]
inputs->model->predictions; parameters->model; labels->loss; predictions->loss
loss->parameters[constraint=false label=update]''')

# %% [markdown]
# ### Limitations Inherent To Machine Learning
#
# From this picture we can now see some fundamental things about training a deep learning model:
#
# - A model cannot be created without data.
# - A model can only learn to operate on the patterns seen in the input data used to train it.
# - This learning approach only creates *predictions*, not recommended *actions*.
# - It's not enough to just have examples of input data; we need *labels* for that data too (e.g., pictures of dogs and cats aren't enough to train a model; we need a label for each one, saying which ones are dogs, and which are cats).
#
# Generally speaking, we've seen that most organizations that say they don't have enough data, actually mean they don't have enough *labeled* data. If any organization is interested in doing something in practice with a model, then presumably they have some inputs they plan to run their model against. And presumably they've been doing that some other way for a while (e.g., manually, or with some heuristic program), so they have data from those processes! For instance, a radiology practice will almost certainly have an archive of medical scans (since they need to be able to check how their patients are progressing over time), but those scans may not have structured labels containing a list of diagnoses or interventions (since radiologists generally create free-text natural language reports, not structured data). We'll be discussing labeling approaches a lot in this notebook, because it's such an important issue in practice.
#
# Since these kinds of machine learning models can only make *predictions* (i.e., attempt to replicate labels), this can result in a significant gap between organizational goals and model capabilities. For instance, in this notebook you'll learn how to create a *recommendation system* that can predict what products a user might purchase. This is often used in e-commerce, such as to customize products shown on a home page by showing the highest-ranked items. But such a model is generally created by looking at a user and their buying history (*inputs*) and what they went on to buy or look at (*labels*), which means that the model is likely to tell you about products the user already has or already knows about, rather than new products that they are most likely to be interested in hearing about. That's very different to what, say, an expert at your local bookseller might do, where they ask questions to figure out your taste, and then tell you about authors or series that you've never heard of before.

# %% [markdown]
# Another critical insight comes from considering how a model interacts with its environment. This can create *feedback loops*, as described here:
#
# - A *predictive policing* model is created based on where arrests have been made in the past. In practice, this is not actually predicting crime, but rather predicting arrests, and is therefore partially simply reflecting biases in existing policing processes.
# - Law enforcement officers then might use that model to decide where to focus their police activity, resulting in increased arrests in those areas.
# - Data on these additional arrests would then be fed back in to retrain future versions of the model.
#
# This is a *positive feedback loop*, where the more the model is used, the more biased the data becomes, making the model even more biased, and so forth.
#
# Feedback loops can also create problems in commercial settings. For instance, a video recommendation system might be biased toward recommending content consumed by the biggest watchers of video (e.g., conspiracy theorists and extremists tend to watch more online video content than the average), resulting in those users increasing their video consumption, resulting in more of those kinds of videos being recommended. We'll consider this topic more in detail in <<chapter_ethics>>.

# %% [markdown]
# Now that you have seen the base of the theory, let's go back to our code example and see in detail how the code corresponds to the process we just described.

# %% [markdown]
# ### How Our Image Recognizer Works

# %% [markdown]
# Let's see just how our image recognizer code maps to these ideas. We'll put each line into a separate cell, and look at what each one is doing (we won't explain every detail of every parameter yet, but will give a description of the important bits; full details will come later in the notebook).

# %% [markdown]
# The first line imports all of the fastai.vision library.
#
# ```python
# from fastai.vision.all import *
# ```
#
# This gives us all of the functions and classes we will need to create a wide variety of computer vision models.

# %% [markdown]
# > J: A lot of Python coders recommend avoiding importing a whole library like this (using the `import *` syntax), because in large software projects it can cause problems. However, for interactive work such as in a Jupyter notebook, it works great. The fastai library is specially designed to support this kind of interactive use, and it will only import the necessary pieces into your environment.

# %% [markdown]
# The second line downloads a standard dataset from the [fast.ai datasets collection](https://course.fast.ai/datasets) (if not previously downloaded) to your server, extracts it (if not previously extracted), and returns a `Path` object with the extracted location:
#
# ```python
# path = untar_data(URLs.PETS)/'images'
# ```

# %% [markdown]
# In the third line we define a function, `is_cat`, labels cats based on a filename rule provided by the dataset creators:
# ```python
# def is_cat(x): return x[0].isupper()
# ```

# %% [markdown]
# We use that function in the fourth line, which tells fastai what kind of dataset we have, and how it is structured:
#
# ```python
# dls = ImageDataLoaders.from_name_func(
#     path, get_image_files(path), valid_pct=0.2, seed=42,
#     label_func=is_cat, item_tfms=Resize(224))
# ```
#
# There are various different classes for different kinds of deep learning datasets and problems—here we're using `ImageDataLoaders`. The first part of the class name will generally be the type of data you have, such as image, or text.
#
# The other important piece of information that we have to tell fastai is how to get the labels from the dataset. Computer vision datasets are normally structured in such a way that the label for an image is part of the filename, or path—most commonly the parent folder name. fastai comes with a number of standardized labeling methods, and ways to write your own. Here we're telling fastai to use the `is_cat` function we just defined.
#
# Finally, we define the `Transform`s that we need. A `Transform` contains code that is applied automatically during training; fastai includes many predefined `Transform`s, and adding new ones is as simple as creating a Python function. There are two kinds: `item_tfms` are applied to each item (in this case, each item is resized to a 224-pixel square), while `batch_tfms` are applied to a *batch* of items at a time using the GPU, so they're particularly fast.
#
# Why 224 pixels? This is the standard size for historical reasons (old pretrained models require this size exactly), but you can pass pretty much anything. If you increase the size, you'll often get a model with better results (since it will be able to focus on more details), but at the price of speed and memory consumption; the opposite is true if you decrease the size.

# %% [markdown]
# > Note: Classification and Regression: _classification_ and _regression_ have very specific meanings in machine learning. These are the two main types of model that we will be investigating in this notebook. A classification model is one which attempts to predict a class, or category. That is, it's predicting from a number of discrete possibilities, such as "dog" or "cat." A regression model is one which attempts to predict one or more numeric quantities, such as a temperature or a location. Sometimes people use the word _regression_ to refer to a particular kind of model called a _linear regression model_; this is a bad practice, and we won't be using that terminology in this notebook!

# %% [markdown]
# The Pet dataset contains 7,390 pictures of dogs and cats, consisting of 37 different breeds. Each image is labeled using its filename: for instance the file *great\_pyrenees\_173.jpg* is the 173rd example of an image of a Great Pyrenees breed dog in the dataset. The filenames start with an uppercase letter if the image is a cat, and a lowercase letter otherwise. We have to tell fastai how to get labels from the filenames, which we do by calling `from_name_func` (which means that labels can be extracted using a function applied to the filename), and passing `is_cat`, which returns `x[0].isupper()`, which evaluates to `True` if the first letter is uppercase (i.e., it's a cat).
#
# The most important parameter to mention here is `valid_pct=0.2`. This tells fastai to hold out 20% of the data and *not use it for training the model at all*. This 20% of the data is called the *validation set*; the remaining 80% is called the *training set*. The validation set is used to measure the accuracy of the model. By default, the 20% that is held out is selected randomly. The parameter `seed=42` sets the *random seed* to the same value every time we run this code, which means we get the same validation set every time we run it—this way, if we change our model and retrain it, we know that any differences are due to the changes to the model, not due to having a different random validation set.
#
# fastai will *always* show you your model's accuracy using *only* the validation set, *never* the training set. This is absolutely critical, because if you train a large enough model for a long enough time, it will eventually memorize the label of every item in your dataset! The result will not actually be a useful model, because what we care about is how well our model works on *previously unseen images*. That is always our goal when creating a model: for it to be useful on data that the model only sees in the future, after it has been trained.
#
# Even when your model has not fully memorized all your data, earlier on in training it may have memorized certain parts of it. As a result, the longer you train for, the better your accuracy will get on the training set; the validation set accuracy will also improve for a while, but eventually it will start getting worse as the model starts to memorize the training set, rather than finding generalizable underlying patterns in the data. When this happens, we say that the model is *overfitting*.
#
# <<img_overfit>> shows what happens when you overfit, using a simplified example where we have just one parameter, and some randomly generated data based on the function `x**2`. As you can see, although the predictions in the overfit model are accurate for data near the observed data points, they are way off when outside of that range.

# %% [markdown]
# ###Example of overfitting

# %%
from IPython.display import Image
Image('./images/att_00000.png')

# %% [markdown]
# **Overfitting is the single most important and challenging issue** when training for all machine learning practitioners, and all algorithms. As you will see, it is very easy to create a model that does a great job at making predictions on the exact data it has been trained on, but it is much harder to make accurate predictions on data the model has never seen before. And of course, this is the data that will actually matter in practice. For instance, if you create a handwritten digit classifier and use it to recognize numbers written on checks, then you are never going to see any of the numbers that the model was trained on—check will have slightly different variations of writing to deal with. You will learn many methods to avoid overfitting in this notebook. However, you should only use those methods aft"er you have confirmed that overfitting is actually occurring (i.e., you have actually observed the validation accuracy getting worse during training). We often see practitioners using over-fitting avoidance techniques even when they have enough data that they didn't need to do so, ending up with a model that may be less accurate than what they could have achieved.

# %% [markdown]
# > important: Validation Set: When you train a model, you must _always_ have both a training set and a validation set, and must measure the accuracy of your model only on the validation set. If you train for too long, with not enough data, you will see the accuracy of your model start to get worse; this is called _overfitting_. fastai defaults `valid_pct` to `0.2`, so even if you forget, fastai will create a validation set for you!

# %% [markdown]
# The fifth line of the code training our image recognizer tells fastai to create a *convolutional neural network* (CNN) and specifies what *architecture* to use (i.e. what kind of model to create), what data we want to train it on, and what *metric* to use:
#
# ```python
# learn = cnn_learner(dls, resnet34, metrics=error_rate)
# ```
#
# Why a CNN? It's the current state-of-the-art approach to creating computer vision models. We'll be learning all about how CNNs work in this notebook. Their structure is inspired by how the human vision system works.
#
# What is a metric? A *metric* is a function that measures the quality of the model's predictions using the validation set, and will be printed at the end of each *epoch*. In this case, we're using `error_rate`, which is a function provided by fastai that does just what it says: tells you what percentage of images in the validation set are being classified incorrectly. Another common metric for classification is `accuracy` (which is just `1.0 - error_rate`). fastai provides many more, which will be discussed throughout.

# %% [markdown]
# The sixth line of our code tells fastai how to *fit* the model:
#
# ```python
# learn.fine_tune(1)
# ```
#
# As we've discussed, the architecture only describes a *template* for a mathematical function; it doesn't actually do anything until we provide values for the millions of parameters it contains.
#
# This is the key to deep learning—determining how to fit the parameters of a model to get it to solve your problem. In order to fit a model, we have to provide at least one piece of information: how many times to look at each image (known as number of *epochs*). The number of epochs you select will largely depend on how much time you have available, and how long you find it takes in practice to fit your model. If you select a number that is too small, you can always train for more epochs later.
#
# But why is the method called `fine_tune`, and not `fit`? fastai actually *does* have a method called `fit`, which does indeed fit a model (i.e. look at images in the training set multiple times, each time updating the parameters to make the predictions closer and closer to the target labels). But in this case, we've started with a pretrained model, and we don't want to throw away all those capabilities that it already has. As you'll learn in this notebook, there are some important tricks to adapt a pretrained model for a new dataset—a process called *fine-tuning*.

# %% [markdown]
# > jargon: Fine-tuning: A transfer learning technique where the parameters of a pretrained model are updated by training for additional epochs using a different task to that used for pretraining.

# %% [markdown]
# So, with all this code our model learned to recognize cats and dogs just from labeled examples. But how did it do it?

# %% [markdown]
# ### What Our Image Recognizer Learned

# %% [markdown]
# At this stage we have an image recognizer that is working very well, but we have no idea what it is actually doing! Although many people complain that deep learning results in impenetrable "black box" models (that is, something that gives predictions but that no one can understand), this really couldn't be further from the truth. There is a vast body of research showing how to deeply inspect deep learning models, and get rich insights from them. Having said that, all kinds of machine learning models (including deep learning, and traditional statistical models) can be challenging to fully understand, especially when considering how they will behave when coming across data that is very different to the data used to train them. We'll be discussing this issue throughout this notebook.
#
# In 2013 a PhD student, Matt Zeiler, and his supervisor, Rob Fergus, published the paper ["Visualizing and Understanding Convolutional Networks"](https://arxiv.org/pdf/1311.2901.pdf), which showed how to visualize the neural network weights learned in each layer of a model. They carefully analyzed the model that won the 2012 ImageNet competition, and used this analysis to greatly improve the model, such that they were able to go on to win the 2013 competition! <<img_layer1>> is the picture that they published of the first layer's weights.

# %%
from IPython.display import Image
Image('/content/DL-Workshop-1/images/layer1.png')

# %% [markdown]
# This picture requires some explanation. For each layer, the image part with the light gray background shows the reconstructed weights pictures, and the larger section at the bottom shows the parts of the training images that most strongly matched each set of weights. For layer 1, what we can see is that the model has discovered weights that represent diagonal, horizontal, and vertical edges, as well as various different gradients. (Note that for each layer only a subset of the features are shown; in practice there are thousands across all of the layers.) These are the basic building blocks that the model has learned for computer vision. They have been widely analyzed by neuroscientists and computer vision researchers, and it turns out that these learned building blocks are very similar to the basic visual machinery in the human eye, as well as the handcrafted computer vision features that were developed prior to the days of deep learning. The next layer is represented in <<img_layer2>>.

# %% [markdown]
# <img src="https://github.com/ItsMeAbby/DL-Workshop-1/blob/master/images/layer2.png?raw=1" alt="Activations of the second layer of a CNN" width="800" caption="Activations of the second layer of a CNN (courtesy of Matthew D. Zeiler and Rob Fergus)" id="img_layer2">

# %% [markdown]
# For layer 2, there are nine examples of weight reconstructions for each of the features found by the model. We can see that the model has learned to create feature detectors that look for corners, repeating lines, circles, and other simple patterns. These are built from the basic building blocks developed in the first layer. For each of these, the right-hand side of the picture shows small patches from actual images which these features most closely match. For instance, the particular pattern in row 2, column 1 matches the gradients and textures associated with sunsets.
#
# <<img_layer3>> shows the image from the paper showing the results of reconstructing the features of layer 3.

# %% [markdown]
# <img src="https://github.com/ItsMeAbby/DL-Workshop-1/blob/master/images/chapter2_layer3.PNG?raw=1" alt="Activations of the third layer of a CNN" width="800" caption="Activations of the third layer of a CNN (courtesy of Matthew D. Zeiler and Rob Fergus)" id="img_layer3">

# %% [markdown]
# As you can see by looking at the righthand side of this picture, the features are now able to identify and match with higher-level semantic components, such as car wheels, text, and flower petals. Using these components, layers four and five can identify even higher-level concepts, as shown in <<img_layer4>>.

# %% [markdown]
# <img src="https://github.com/ItsMeAbby/DL-Workshop-1/blob/master/images/chapter2_layer4and5.PNG?raw=1" alt="Activations of layers 4 and 5 of a CNN" width="800" caption="Activations of layers 4 and 5 of a CNN (courtesy of Matthew D. Zeiler and Rob Fergus)" id="img_layer4">

# %% [markdown]
# This article was studying an older model called *AlexNet* that only contained five layers. Networks developed since then can have hundreds of layers—so you can imagine how rich the features developed by these models can be!
#
# When we fine-tuned our pretrained model earlier, we adapted what those last layers focus on (flowers, humans, animals) to specialize on the cats versus dogs problem. More generally, we could specialize such a pretrained model on many different tasks. Let's have a look at some examples.

# %% [markdown]
# ### Image Recognizers Can Tackle Non-Image Tasks

# %% [markdown]
# An image recognizer can, as its name suggests, only recognize images. But a lot of things can be represented as images, which means that an image recogniser can learn to complete many tasks.
#
# For instance, a sound can be converted to a spectrogram, which is a chart that shows the amount of each frequency at each time in an audio file. Fast.ai student Ethan Sutin used this approach to easily beat the published accuracy of a state-of-the-art [environmental sound detection model](https://medium.com/@etown/great-results-on-audio-classification-with-fastai-library-ccaf906c5f52) using a dataset of 8,732 urban sounds. fastai's `show_batch` clearly shows how each different sound has a quite distinctive spectrogram, as you can see in <<img_spect>>.

# %% [markdown]
# <img alt="show_batch with spectrograms of sounds" width="400" caption="show_batch with spectrograms of sounds" id="img_spect" src="https://github.com/ItsMeAbby/DL-Workshop-1/blob/master/images/att_00012.png?raw=1">

# %% [markdown]
# A time series can easily be converted into an image by simply plotting the time series on a graph. However, it is often a good idea to try to represent your data in a way that makes it as easy as possible to pull out the most important components. In a time series, things like seasonality and anomalies are most likely to be of interest. There are various transformations available for time series data. For instance, fast.ai student Ignacio Oguiza created images from a time series dataset for olive oil classification, using a technique called Gramian Angular Difference Field (GADF); you can see the result in <<ts_image>>. He then fed those images to an image classification model just like the one you see in this chapter. His results, despite having only 30 training set images, were well over 90% accurate, and close to the state of the art.

# %% [markdown]
# <img alt="Converting a time series into an image" width="700" caption="Converting a time series into an image" id="ts_image" src="https://github.com/ItsMeAbby/DL-Workshop-1/blob/master/images/att_00013.png?raw=1">

# %% [markdown]
# Another interesting fast.ai student project example comes from Gleb Esman. He was working on fraud detection at Splunk, using a dataset of users' mouse movements and mouse clicks. He turned these into pictures by drawing an image where the position, speed, and acceleration of the mouse pointer was displayed using coloured lines, and the clicks were displayed using [small colored circles](https://www.splunk.com/en_us/blog/security/deep-learning-with-splunk-and-tensorflow-for-security-catching-the-fraudster-in-neural-networks-with-behavioral-biometrics.html), as shown in <<splunk>>. He then fed this into an image recognition model just like the one we've used in this chapter, and it worked so well that it led to a patent for this approach to fraud analytics!

# %% [markdown]
# <img alt="Converting computer mouse behavior to an image" width="450" caption="Converting computer mouse behavior to an image" id="splunk" src="https://github.com/ItsMeAbby/DL-Workshop-1/blob/master/images/att_00014.png?raw=1">

# %% [markdown]
# Another example comes from the paper ["Malware Classification with Deep Convolutional Neural Networks"](https://ieeexplore.ieee.org/abstract/document/8328749) by Mahmoud Kalash et al., which explains that "the malware binary file is divided into 8-bit sequences which are then converted to equivalent decimal values. This decimal vector is reshaped and a gray-scale image is generated that represents the malware sample," like in <<malware_proc>>.

# %% [markdown]
# <img alt="Malware classification process" width="623" caption="Malware classification process" id="malware_proc" src="https://github.com/ItsMeAbby/DL-Workshop-1/blob/master/images/att_00055.png?raw=1">

# %% [markdown]
# The authors then show "pictures" generated through this process of malware in different categories, as shown in <<malware_eg>>.

# %% [markdown]
# <img alt="Malware examples" width="650" caption="Malware examples" id="malware_eg" src="https://github.com/ItsMeAbby/DL-Workshop-1/blob/master/images/att_00056.png?raw=1">

# %% [markdown]
# As you can see, the different types of malware look very distinctive to the human eye. The model the researchers trained based on this image representation was more accurate at malware classification than any previous approach shown in the academic literature. This suggests a good rule of thumb for converting a dataset into an image representation: if the human eye can recognize categories from the images, then a deep learning model should be able to do so too.
#
# In general, you'll find that a small number of general approaches in deep learning can go a long way, if you're a bit creative in how you represent your data! You shouldn't think of approaches like the ones described here as "hacky workarounds," because actually they often (as here) beat previously state-of-the-art results. These really are the right ways to think about these problem domains.

# %% [markdown]
# ### Jargon Recap

# %% [markdown]
# We just covered a lot of information so let's recap briefly, <<dljargon>> provides a handy vocabulary.
#
# ```asciidoc
# [[dljargon]]
# .Deep learning vocabulary
# [options="header"]
# |=====
# | Term | Meaning
# |Label | The data that we're trying to predict, such as "dog" or "cat"
# |Architecture | The _template_ of the model that we're trying to fit; the actual mathematical function that we're passing the input data and parameters to
# |Model | The combination of the architecture with a particular set of parameters
# |Parameters | The values in the model that change what task it can do, and are updated through model training
# |Fit | Update the parameters of the model such that the predictions of the model using the input data match the target labels
# |Train | A synonym for _fit_
# |Pretrained model | A model that has already been trained, generally using a large dataset, and will be fine-tuned
# |Fine-tune | Update a pretrained model for a different task
# |Epoch | One complete pass through the input data
# |Loss | A measure of how good the model is, chosen to drive training via SGD
# |Metric | A measurement of how good the model is, using the validation set, chosen for human consumption
# |Validation set | A set of data held out from training, used only for measuring how good the model is
# |Training set | The data used for fitting the model; does not include any data from the validation set
# |Overfitting | Training a model in such a way that it _remembers_ specific features of the input data, rather than generalizing well to data not seen during training
# |CNN | Convolutional neural network; a type of neural network that works particularly well for computer vision tasks
# |=====
# ```

# %% [markdown]
# With this vocabulary in hand, we are now in a position to bring together all the key concepts introduced so far. Take a moment to review those definitions and read the following summary. If you can follow the explanation, then you're well equipped to understand the discussions to come.
#
# *Machine learning* is a discipline where we define a program not by writing it entirely ourselves, but by learning from data. *Deep learning* is a specialty within machine learning that uses *neural networks* with multiple *layers*. *Image classification* is a representative example (also known as *image recognition*). We start with *labeled data*; that is, a set of images where we have assigned a *label* to each image indicating what it represents. Our goal is to produce a program, called a *model*, which, given a new image, will make an accurate *prediction* regarding what that new image represents.
#
# Every model starts with a choice of *architecture*, a general template for how that kind of model works internally. The process of *training* (or *fitting*) the model is the process of finding a set of *parameter values* (or *weights*) that specialize that general architecture into a model that works well for our particular kind of data. In order to define how well a model does on a single prediction, we need to define a *loss function*, which determines how we score a prediction as good or bad.
#
# To make the training process go faster, we might start with a *pretrained model*—a model that has already been trained on someone else's data. We can then adapt it to our data by training it a bit more on our data, a process called *fine-tuning*.
#
# When we train a model, a key concern is to ensure that our model *generalizes*—that is, that it learns general lessons from our data which also apply to new items it will encounter, so that it can make good predictions on those items. The risk is that if we train our model badly, instead of learning general lessons it effectively memorizes what it has already seen, and then it will make poor predictions about new images. Such a failure is called *overfitting*. In order to avoid this, we always divide our data into two parts, the *training set* and the *validation set*. We train the model by showing it only the training set and then we evaluate how well the model is doing by seeing how well it performs on items from the validation set. In this way, we check if the lessons the model learns from the training set are lessons that generalize to the validation set. In order for a person to assess how well the model is doing on the validation set overall, we define a *metric*. During the training process, when the model has seen every item in the training set, we call that an *epoch*.
#
# All these concepts apply to machine learning in general. That is, they apply to all sorts of schemes for defining a model by training it with data. What makes deep learning distinctive is a particular class of architectures: the architectures based on *neural networks*. In particular, tasks like image classification rely heavily on *convolutional neural networks*, which we will discuss shortly.

# %% [markdown]
# ### End sidebar

# %% [markdown]
# If you ever have any questions about a fastai method, you should use the function `doc`, passing it the method name:
#
# ```python
# doc(learn.predict)
# ```
#
# This will make a small window pop up with content like this:
#
# <img src="https://github.com/ItsMeAbby/DL-Workshop-1/blob/master/images/doc_ex.png?raw=1" width="600">

# %% [markdown]
# A brief one-line explanation is provided by `doc`. The "Show in docs" link takes you to the full documentation, where you'll find all the details and lots of examples. Also, most of fastai's methods are just a handful of lines, so you can click the "source" link to see exactly what's going on behind the scenes.
#
# Let's move on to something much less sexy, but perhaps significantly more widely commercially useful: building models from plain *tabular* data.

# %% [markdown]
# ### End sidebar

# %% [markdown]
# Each of the models we trained showed a training and validation loss. A good validation set is one of the most important pieces of the training process. Let's see why and learn how to create one.

# %% [markdown]
# ## Validation Sets and Test Sets

# %% [markdown]
# As we've discussed, the goal of a model is to make predictions about data. But the model training process is fundamentally dumb. If we trained a model with all our data, and then evaluated the model using that same data, we would not be able to tell how well our model can perform on data it hasn’t seen. Without this very valuable piece of information to guide us in training our model, there is a very good chance it would become good at making predictions about that data but would perform poorly on new data.
#
# To avoid this, our first step was to split our dataset into two sets: the *training set* (which our model sees in training) and the *validation set*, also known as the *development set* (which is used only for evaluation). This lets us test that the model learns lessons from the training data that generalize to new data, the validation data.
#
# One way to understand this situation is that, in a sense, we don't want our model to get good results by "cheating." If it makes an accurate prediction for a data item, that should be because it has learned characteristics of that kind of item, and not because the model has been shaped by *actually having seen that particular item*.
#
# Splitting off our validation data means our model never sees it in training and so is completely untainted by it, and is not cheating in any way. Right?
#
# In fact, not necessarily. The situation is more subtle. This is because in realistic scenarios we rarely build a model just by training its weight parameters once. Instead, we are likely to explore many versions of a model through various modeling choices regarding network architecture, learning rates, data augmentation strategies, and other factors we will discuss in upcoming chapters. Many of these choices can be described as choices of *hyperparameters*. The word reflects that they are parameters about parameters, since they are the higher-level choices that govern the meaning of the weight parameters.

# %% [markdown]
# The problem is that even though the ordinary training process is only looking at predictions on the training data when it learns values for the weight parameters, the same is not true of us. We, as modelers, are evaluating the model by looking at predictions on the validation data when we decide to explore new hyperparameter values! So subsequent versions of the model are, indirectly, shaped by us having seen the validation data. Just as the automatic training process is in danger of overfitting the training data, we are in danger of overfitting the validation data through human trial and error and exploration.
#
# The solution to this conundrum is to introduce another level of even more highly reserved data, the *test set*. Just as we hold back the validation data from the training process, we must hold back the test set data even from ourselves. It cannot be used to improve the model; it can only be used to evaluate the model at the very end of our efforts. In effect, we define a hierarchy of cuts of our data, based on how fully we want to hide it from training and modeling processes: training data is fully exposed, the validation data is less exposed, and test data is totally hidden. This hierarchy parallels the different kinds of modeling and evaluation processes themselves—the automatic training process with back propagation, the more manual process of trying different hyper-parameters between training sessions, and the assessment of our final result.
#
# The test and validation sets should have enough data to ensure that you get a good estimate of your accuracy. If you're creating a cat detector, for instance, you generally want at least 30 cats in your validation set. That means that if you have a dataset with thousands of items, using the default 20% validation set size may be more than you need. On the other hand, if you have lots of data, using some of it for validation probably doesn't have any downsides.
#
# Having two levels of "reserved data"—a validation set and a test set, with one level representing data that you are virtually hiding from yourself—may seem a bit extreme. But the reason it is often necessary is because models tend to gravitate toward the simplest way to do good predictions (memorization), and we as fallible humans tend to gravitate toward fooling ourselves about how well our models are performing. The discipline of the test set helps us keep ourselves intellectually honest. That doesn't mean we *always* need a separate test set—if you have very little data, you may need to just have a validation set—but generally it's best to use one if at all possible.
#
# This same discipline can be critical if you intend to hire a third party to perform modeling work on your behalf. A third party might not understand your requirements accurately, or their incentives might even encourage them to misunderstand them. A good test set can greatly mitigate these risks and let you evaluate whether their work solves your actual problem.
#
# To put it bluntly, if you're a senior decision maker in your organization (or you're advising senior decision makers), the most important takeaway is this: if you ensure that you really understand what test and validation sets are and why they're important, then you'll avoid the single biggest source of failures we've seen when organizations decide to use AI. For instance, if you're considering bringing in an external vendor or service, make sure that you hold out some test data that the vendor *never gets to see*. Then *you* check their model on your test data, using a metric that *you* choose based on what actually matters to you in practice, and *you* decide what level of performance is adequate. (It's also a good idea for you to try out some simple baseline yourself, so you know what a really simple model can achieve. Often it'll turn out that your simple model performs just as well as one produced by an external "expert"!)

# %% [markdown]
# ### Use Judgment in Defining Test Sets

# %% [markdown]
# To do a good job of defining a validation set (and possibly a test set), you will sometimes want to do more than just randomly grab a fraction of your original dataset. Remember: a key property of the validation and test sets is that they must be representative of the new data you will see in the future. This may sound like an impossible order! By definition, you haven’t seen this data yet. But you usually still do know some things.
#
# It's instructive to look at a few example cases. Many of these examples come from predictive modeling competitions on the [Kaggle](https://www.kaggle.com/) platform, which is a good representation of problems and methods you might see in practice.
#
# One case might be if you are looking at time series data. For a time series, choosing a random subset of the data will be both too easy (you can look at the data both before and after the dates you are trying to predict) and not representative of most business use cases (where you are using historical data to build a model for use in the future). If your data includes the date and you are building a model to use in the future, you will want to choose a continuous section with the latest dates as your validation set (for instance, the last two weeks or last month of available data).
#
# Suppose you want to split the time series data in <<timeseries1>> into training and validation sets.

# %% [markdown]
# <img src="https://github.com/ItsMeAbby/DL-Workshop-1/blob/master/images/timeseries1.png?raw=1" width="400" id="timeseries1" caption="A time series" alt="A serie of values">

# %% [markdown]
# A random subset is a poor choice (too easy to fill in the gaps, and not indicative of what you'll need in production), as we can see in <<timeseries2>>.

# %% [markdown]
# <img src="https://github.com/ItsMeAbby/DL-Workshop-1/blob/master/images/timeseries2.png?raw=1" width="400" id="timeseries2" caption="A poor training subset" alt="Random training subset">

# %% [markdown]
# Instead, use the earlier data as your training set (and the later data for the validation set), as shown in <<timeseries3>>.

# %% [markdown]
# <img src="https://github.com/ItsMeAbby/DL-Workshop-1/blob/master/images/timeseries3.png?raw=1" width="400" id="timeseries3" caption="A good training subset" alt="Training subset using the data up to a certain timestamp">

# %% [markdown]
# For example, Kaggle had a competition to [predict the sales in a chain of Ecuadorian grocery stores](https://www.kaggle.com/c/favorita-grocery-sales-forecasting). Kaggle's training data ran from Jan 1 2013 to Aug 15 2017, and the test data spanned Aug 16 2017 to Aug 31 2017. That way, the competition organizer ensured that entrants were making predictions for a time period that was *in the future*, from the perspective of their model. This is similar to the way quant hedge fund traders do *back-testing* to check whether their models are predictive of future periods, based on past data.

# %% [markdown]
# A second common case is when you can easily anticipate ways the data you will be making predictions for in production may be *qualitatively different* from the data you have to train your model with.
#
# In the Kaggle [distracted driver competition](https://www.kaggle.com/c/state-farm-distracted-driver-detection), the independent variables are pictures of drivers at the wheel of a car, and the dependent variables are categories such as texting, eating, or safely looking ahead. Lots of pictures are of the same drivers in different positions, as we can see in <<img_driver>>. If you were an insurance company building a model from this data, note that you would be most interested in how the model performs on drivers it hasn't seen before (since you would likely have training data only for a small group of people). In recognition of this, the test data for the competition consists of images of people that don't appear in the training set.

# %% [markdown]
# <img src="https://github.com/ItsMeAbby/DL-Workshop-1/blob/master/images/driver.PNG?raw=1" width="600" id="img_driver" caption="Two pictures from the training data" alt="Two pictures from the training data, showing the same driver">

# %% [markdown]
# If you put one of the images in <<img_driver>> in your training set and one in the validation set, your model will have an easy time making a prediction for the one in the validation set, so it will seem to be performing better than it would on new people. Another perspective is that if you used all the people in training your model, your model might be overfitting to particularities of those specific people, and not just learning the states (texting, eating, etc.).
#
# A similar dynamic was at work in the [Kaggle fisheries competition](https://www.kaggle.com/c/the-nature-conservancy-fisheries-monitoring) to identify the species of fish caught by fishing boats in order to reduce illegal fishing of endangered populations.  The test set consisted of boats that didn't appear in the training data.  This means that you'd want your validation set to include boats that are not in the training set.
#
# Sometimes it may not be clear how your validation data will differ.  For instance, for a problem using satellite imagery, you'd need to gather more information on whether the training set just contained certain geographic locations, or if it came from geographically scattered data.

# %%
#Now that you have gotten a taste of how to build a model, you can decide what you want to dig into next.

# %% [markdown]
# ## A _Choose Your Own Adventure_ moment

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# It can be hard to know in pages and pages of prose what the key things are that you really need to focus on and remember. So, we've prepared a list of questions and suggested steps to complete.

# %% [markdown]
# 1. Do you need these for deep learning?
#
#    - Lots of math T / F
#    - Lots of data T / F
#    - Lots of expensive computers T / F
#    - A PhD T / F
#
# 1. Name five areas where deep learning is now the best in the world.
# 1. What were the two theoretical misunderstandings that held back the field of neural networks?
# 1. What is a GPU?
# 1. Open a notebook and execute a cell containing: `1+1`. What happens?
# 1. Follow through each cell of the stripped version of the notebook for this session. Before executing each cell, guess what will happen.
# 1. Why is it hard to use a traditional computer program to recognize images in a photo?
# 1. What is meant by "weight assignment"?
# 1. What term do we normally use in deep learning for "weights"?
# 1. Why is it hard to understand why a deep learning model makes a particular prediction?
# 1. What do you need in order to train a model?
# 1. How could a feedback loop impact the rollout of a predictive policing model?
# 1. Do we always have to use 224×224-pixel images with the cat recognition model?
# 1. What is the difference between classification and regression?
# 1. What is a validation set? What is a test set? Why do we need them?
# 1. What will fastai do if you don't provide a validation set?
# 1. Can we always use a random sample for a validation set? Why or why not?
# 1. What is overfitting? Provide an example.
# 1. What is a metric? How does it differ from "loss"?
# 1. How can pretrained models help?
# 1. What is the "head" of a model?
# 1. What kinds of features do the early layers of a CNN find? How about the later layers?
# 1. Are image models only useful for photos?
# 1. What is an "architecture"?
# 1. What is segmentation?
# 1. What is `y_range` used for? When do we need it?
# 1. What are "hyperparameters"?
# 1. What's the best way to avoid failures when using AI in an organization?

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. Why is a GPU useful for deep learning? How is a CPU different, and why is it less effective for deep learning?
# 1. Try to think of three areas where feedback loops might impact the use of machine learning. See if you can find documented examples of that happening in practice.
